# %%
import requests
url = 'http://daili.spbeen.com/user_info/person/'

cookie = {
    'UM_distinctid':'16cc395286467-0d41d5729fb3a5-7373e61-10c13a-16cc3952865710',
    'CNZZDATA1274503826':'777013918-1562839266-%7C1568187396',
    'csrftoken':'7KZT5T9XcEFOzxC8e2gRirfO0doHcALh1X3XAuiQgbJGbxlGSTitUWGQaA7Or5Z9', 
    '_dfesp':'uv2zy6r1ryevgce2i3bb07zqronyr8d3',
}

# %%
response = requests.get(url) # 没有cookie，未登录状态下

# %%
response.history[0].url
# Out:
# 'http://daili.spbeen.com/user_info/person/'

# %%
response.url
# Out:
# 'http://daili.spbeen.com/accounts/login/?next=/user_info/person/'

# %%
resp = requests.get(url, cookies=cookie) # 登录状态下

# %%
resp.url
# Out:
# 'http://daili.spbeen.com/user_info/person/'

# %%
print(resp.text)
# Out:
# <!DOCTYPE html>
# <html>
#
# <head>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <title>详细资料|个人信息</title>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/bulma/0.7.1/css/bulma.min.css">
#
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/animate.css/3.5.2/animate.min.css">
#
# <script defer src="https://use.fontawesome.com/releases/v5.1.0/js/all.js"></script>
# <script src="https://cdn.bootcss.com/jquery/1.12.4/jquery.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/vue/dist/vue.js"></script>
#
#     <style>
#         p.ips{
#             text-align: center;
#             background-color: #23d160;
#             border-radius: 4px;
#             color: white;
#         }
#
#     </style>
# </head>
#
# <body>
#     <nav class="navbar is-black is-fixed-top" role="navigation" aria-label="main navigation">
#     <div class="container">
# ...
